# %%
import glob
import os
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\DATA ENGINEER\AWS S3 raw data\gm_review_NJ_raw.parquet"

# %% [markdown]
# # nj_rev_raw

# %%
nj_rev_raw = pd.read_parquet(file_path)

# %%
print(f"File size:", os.path.getsize(file_path)  / (1024 * 1024), "MB")
# Out:
# File size: 159.9847936630249 MB

# %%
nj_rev_raw.head()
# Out:
#         user_id               name           time  rating  \
# 0  1.011903e+20       Monica Zobbi  1614634731992       5
# 1  1.172699e+20  Vitaliia Stefurak  1572974792541       5
# 2  1.152270e+20       Maria Guzman  1578525387607       5
# 3  1.161828e+20             Jo Rad  1602103279588       5
# 4  1.010712e+20     Kimberly Hults  1593034107348       5
#
#                                                 text  pics  \
# 0  Viktoriya is always very professional and atte...  None
# 1  If I could leave them 10 starts I would , unbe...  None
# 2  Laura took her time to know my hair and what s...  None
# 3  Wow, what an experience! Haircut by Victoria! ...  None
# 4  Love this salon! The great experience starts o...  None
#
#                                                 resp  \
# 0                                               None
# 1                                               None
# 2                                               None
# ...

# %%
file_path = r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\DATA ENGINEER\AWS S3 raw data\gm_sitios_raw.parquet"

# %%
print(f"File size:", os.path.getsize(file_path)  / (1024 * 1024), "MB")
# Out:
# File size: 977.0309982299805 MB

# %% [markdown]
# # gm_sitios_raw

# %%
gm_sitios_raw = pd.read_parquet(file_path)
gm_sitios_raw.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#                 category  avg_rating  num_of_reviews price  \
# ...

# %%
file_path = r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\DATA ENGINEER\AWS S3 raw data\gm_review_NY_raw.parquet"

# %%
print(f"File size:", os.path.getsize(file_path)  / (1024 * 1024), "MB")
# Out:
# File size: 228.5619077682495 MB

# %% [markdown]
# # ny_rev_raw

# %%
ny_rev_raw = pd.read_parquet(file_path)
ny_rev_raw.head()
# Out:
#         user_id             name           time  rating  \
# 0  1.137221e+20   Alvin Martinez  1603494795361       5
# 1  1.072934e+20  Johnnie Jackson  1620157037403       1
# 2  1.003786e+20     Manie Blazer  1597431662039       5
# 3  1.149982e+20   Fashion Fiinds  1543773862044       5
# 4  1.171782e+20   Andres Rieloff  1597279097718       1
#
#                                                 text  \
# 0  I'm late to posting this but this store especi...
# 1  Very dissatisfied I did not get my phone the p...
# 2  Excellent very well done with professional car...
# 3  Basing my review strictly on the service I rec...
# 4  Bad! Disorganized. I'm being totally honest. I...
#
#                                                 pics  \
# 0  [{"url":["https://lh5.googleusercontent.com/p/...
# 1                                               None
# 2                                               None
# 3                                               None
# ...

# %% [markdown]
# # Test dataset reducidos

# %%
gm_sitios_red = pd.read_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\datasets\S3\gm_sitios_raw_red.parquet")

# gm_sitios_red['name'][0]

gm_sitios_red.head(2)
# Out:
#                name                                            address  \
# 0    Gulistan Pizza  Gulistan Pizza, 783 S Orange Ave, Newark, NJ 0...
# 1  Pfeffer's Market  Pfeffer's Market, 297 Shell Rd, Carneys Point,...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x89c3acab12c10d5d:0x73285fc4bd781796        None  40.745207 -74.220116
# 1  0x89c71d8585020cd5:0x7c18f0acaac87f17        None  39.709561 -75.470117
#
#                category  avg_rating  num_of_reviews price  \
# 0  ["Pizza restaurant"]         3.3               8  None
# 1  ["Pizza restaurant"]         4.9               7  None
#
#                                                hours  \
# 0                                               None
# 1  [["Wednesday","8:30AM\u20138:30PM"],["Thursday...
#
#                                                 MISC state  \
# 0  {"Service options":["Delivery"],"Amenities":["...    NJ
# ...

# %%
gm_sitios_red.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
gm_sitios_red = gm_sitios_red.drop(columns=['address', 'description', 'latitude', 'longitude', 'category', 'price', 'hours', 'MISC', 'state', 'relative_results', 'url'])

gm_sitios_red.columns
# Out:
# Index(['name', 'gmap_id', 'avg_rating', 'num_of_reviews'], dtype='object')
