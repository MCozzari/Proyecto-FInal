# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
gm_rev_10pc = pd.read_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\Victoria\25-02-2025\gm_rev_raw_10PC.parquet")

gm_sitios_10pc = pd.read_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\Victoria\25-02-2025\gm_sitios_raw_10PC.parquet")

# %%
# Extraer una fila aleatoria de cada dataset
fila_rev = gm_rev_10pc.sample(1)
fila_sitios = gm_sitios_10pc.sample(1)

# Eliminar la fila extraída de los datasets originales
gm_rev_10pc = gm_rev_10pc.drop(fila_rev.index)
gm_sitios_10pc = gm_sitios_10pc.drop(fila_sitios.index)

# Crear las versiones pequeñas con la fila extraída
gm_rev_test = fila_rev.copy()
gm_sitios_test = fila_sitios.copy()

# %%
print(gm_rev_test['name'],
      '\n',
      '\n',
      gm_sitios_test['name'])
# Out:
# 2840    Luis Ruiz-Gaston
# Name: name, dtype: object
#
#  131886    Community Montessori School
# Name: name, dtype: object

# %%
# Guardar los datasets reducidos y pequeños en nuevos archivos
gm_rev_10pc.to_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\datasets\S3\gm_rev_10pc_reducido.parquet") # gm_rev_raw_10PC.parquet
gm_sitios_10pc.to_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\datasets\S3\gm_sitios_10pc_reducido.parquet") # gm_sitios_raw_10PC.parquet

gm_rev_test.to_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\datasets\S3\gm_rev_test.parquet.parquet") # gm_rev_test.parquet
gm_sitios_test.to_parquet(r"C:\Users\felip\Desktop\Stuff\Cursos\SoyHenry\Clases\LABS\PF\PF_google_yelp\Proyecto-FInal\Proyecto-FInal\datasets\S3\gm_sitios_test.parquet") # gm_sitios_test.parquet
